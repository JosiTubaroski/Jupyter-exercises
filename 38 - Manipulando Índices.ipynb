# %% [markdown]
# ### Manipulando Índices

# %%
import numpy as np
import pandas as pd

# %%
file="C:\\projetos\\drinks.csv"
drinks = pd.read_csv(file)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent
# 0                           0.0  34.660.000      Asia
# 1                           4.9   2.876.000    Europe
# 2                           0.7  40.061.000    Africa
# 3                          12.4  77.281.000    Europe
# 4                           5.9  28.081.000    Africa

# %%
#Qualquer Dataframe possui um índice

drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
#As colunas também estão armazenadas em um objeto de índices.

drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'population', 'continent'],
#       dtype='object')

# %%
# Indices ou colunas não são incluidas no shape
drinks.shape
# Out:
# (193, 7)

# %% [markdown]
# ### Identificação

# %%
#Na identificação, o indice permanece com cada linha quando filtramos um Dataframe

drinks[drinks.continent=='Asia']
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# 82                 Israel             63               69              9
# 85                  Japan             77              202             16
# 86                 Jordan              6               21              1
# 87             Kazakhstan            124              246             12
# 90                 Kuwait              0                0              0
# 91             Kyrgyzstan             31               97              6
# 92                   Laos             62                0            123
# 94                Lebanon             20               55             31
# 102              Malaysia             13                4              0
# 103              Maldives              0                0              0
# 112              Mongolia             77              189              8
# 116               Myanmar              5                1              0
# 119                 Nepal              5                6              0
# 127                  Oman             22               16              1
# 128              Pakistan              0                0              0
# 134           Philippines             71              186              1
# 137                 Qatar              1               42              7
# 138           South Korea            140               16              9
# 141    Russian Federation            247              326             73
# 149          Saudi Arabia              0                5              0
# 154             Singapore             60               12             11
# 161             Sri Lanka             16              104              0
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 171           Timor-Leste              1                1              4
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 181  United Arab Emirates             16              135              5
# 186            Uzbekistan             25              101              8
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
#
#      total_litres_of_pure_alcohol     population continent
# 0                             0.0     34.660.000      Asia
# 12                            2.0      1.359.800      Asia
# 13                            0.0    159.145.000      Asia
# 19                            0.4        765.650      Asia
# 24                            0.6        393.372      Asia
# 30                            2.2     15.405.157      Asia
# 36                            5.0  1.372.470.000      Asia
# 46                            0.0     25.155.000      Asia
# 77                            2.2  1.278.160.000      Asia
# 78                            0.1    255.780.000      Asia
# 79                            0.0     78.690.300      Asia
# 80                            0.2     36.004.552      Asia
# 82                            2.5      8.412.000      Asia
# 85                            7.0    126.832.000      Asia
# 86                            0.5      7.595.000      Asia
# 87                            6.8     17.563.300      Asia
# 90                            0.0      3.268.431      Asia
# 91                            2.4      6.083.000      Asia
# 92                            6.2      6.802.000      Asia
# 94                            1.9      4.168.000      Asia
# 102                           0.3     30.727.000      Asia
# 103                           0.0        341.256      Asia
# 112                           4.9      3.037.675      Asia
# 116                           0.1     53.897.000      Asia
# 119                           0.2     28.037.904      Asia
# 127                           0.7      4.257.568      Asia
# 128                           0.0    209.156.000      Asia
# 134                           4.6    102.157.500      Asia
# 137                           0.9      2.120.129      Asia
# 138                           9.8     51.482.816      Asia
# 141                          11.5    146.606.730      Asia
# 149                           0.1     31.521.418      Asia
# 154                           1.5      5.535.000      Asia
# 161                           2.2     20.675.000      Asia
# 167                           1.0     23.412.429      Asia
# 168                           0.3      8.468.555      Asia
# 169                           6.4     65.104.000      Asia
# 171                           0.1      1.212.107      Asia
# 176                           1.4     77.695.000      Asia
# 177                           2.2      5.663.000      Asia
# 181                           2.8      9.157.000      Asia
# 186                           2.4     31.022.500      Asia
# 189                           2.0     93.448.000      Asia
# 190                           0.1     27.058.000      Asia

# %% [markdown]
# ### Localização

# %%
# Na seleção podemos trazer uma parte do Dataframe utilizando o indice

# A função Loc permite a localização por índice

drinks.loc[6, 'beer_servings']
# Out:
# 193

# %% [markdown]
# ### Alterando Índices

# %% [markdown]
# #### A alteração de índices reflete no Dataframe na forma de agrupamentos ou reshaping

# %%
#Alterando o índice para países com opção implace, que refletirá no Dataframe ORIGINAL

drinks.set_index('country', inplace=True)
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol  population continent
# country
# Afghanistan                           0.0  34.660.000      Asia
# Albania                               4.9   2.876.000    Europe
# Algeria                               0.7  40.061.000    Africa
# Andorra                              12.4  77.281.000    Europe
# Angola                                5.9  28.081.000    Africa

# %%
# Utilizando a função Loc mais uma vez para trazer uma parte do Dataframe

drinks.loc['Brazil', 'beer_servings']
# Out:
# 245

# %% [markdown]
# ### Nomeando índices

# %%
# Podemos nomear os índices, mas essa característica é opcional, porém, recomendada em produção e documentação

drinks.index.name = None
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol  population continent
# Afghanistan                           0.0  34.660.000      Asia
# Albania                               4.9   2.876.000    Europe
# Algeria                               0.7  40.061.000    Africa
# Andorra                              12.4  77.281.000    Europe
# Angola                                5.9  28.081.000    Africa

# %% [markdown]
# ### Resetando um índice

# %%
drinks.reset_index(inplace=True)
drinks.head()
# Out:
#          index  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent
# 0                           0.0  34.660.000      Asia
# 1                           4.9   2.876.000    Europe
# 2                           0.7  40.061.000    Africa
# 3                          12.4  77.281.000    Europe
# 4                           5.9  28.081.000    Africa

# %% [markdown]
# ### Métodos de Dataframes em Séries

# %%
# Podemos mesclar praticamente todos os métodos dos Dataframes
# Aqui por exemplo, o describe retorna um novo Dataframe

drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# Que pode ser utilizado pelo método Loc.
# Qual a média de cerveja consumida no mundo inteiro

drinks.describe().loc['mean', 'beer_servings']
# Out:
# 106.16062176165804

# %%
# Toda série tambem possui um indice, que é carregado a partir do Dataframe

drinks.continent.tail()
# Out:
# 188    South America
# 189             Asia
# 190             Asia
# 191           Africa
# 192           Africa
# Name: continent, dtype: object

# %%
# Alterando o índice mais uma vez

drinks.set_index('country', inplace=True)

# %%
# Verificando uma série do Dataframe

drinks.continent.head()
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
# Um outro exemplo de séries retornada, é quando utilizamos o value_counts()

drinks.continent.value_counts().index
# Out:
# Index(['Africa', 'Europe', 'Asia', 'North America', 'Oceania',
#        'South America'],
#       dtype='object')

# %%
# Acessando os valores da série

drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
# Os elementos de uma série podem ser selecionados utilizando a notação de brackets

drinks.continent.value_counts()['Africa']
# Out:
# 53

# %% [markdown]
# ### Ordenando Séries

# %%
# Qualquer série pode ter os seus valores ordenados por valores

drinks.continent.value_counts().sort_values()
# Out:
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# Name: continent, dtype: int64

# %%
# Qualquer série pode ter os seus valores ordenados por índices

drinks.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %% [markdown]
# ### Alinhamento

# %%
# A coluna beer_servings contém a média anual de cerveja consumida por pessoa
drinks.beer_servings.head()
# Out:
# country
# Afghanistan      0
# Albania         89
# Algeria         25
# Andorra        245
# Angola         217
# Name: beer_servings, dtype: int64

# %%
# Supondo uma classificação: 0 - 75 = Baixa / 76 - 150 = Media / 151 - .... Alta
# Vamos criar outra série baseada e ALINHADA a primeira

cons_beer = pd.Series(['Baixo', 'Baixo', 'Alto'], index=['Afghanistan', 'Albania', 'Andorra'], name='consumo')
cons_beer
# Out:
# Afghanistan    Baixo
# Albania        Baixo
# Andorra         Alto
# Name: consumo, dtype: object

# %%
# Concatene as séries ou dataframes

pd.concat([drinks, cons_beer], axis=1).head(20)
# Out:
#                    beer_servings  spirit_servings  wine_servings  \
# Afghanistan                    0                0              0
# Albania                       89              132             54
# Algeria                       25                0             14
# Andorra                      245              138            312
# Angola                       217               57             45
# Antigua & Barbuda            102              128             45
# Argentina                    193               25            221
# Armenia                       21              179             11
# Australia                    261               72            212
# Austria                      279               75            191
# Azerbaijan                    21               46              5
# Bahamas                      122              176             51
# Bahrain                       42               63              7
# Bangladesh                     0                0              0
# Barbados                     143              173             36
# Belarus                      142              373             42
# Belgium                      295               84            212
# Belize                       263              114              8
# Benin                         34                4             13
# Bhutan                        23                0              0
#
#                    total_litres_of_pure_alcohol   population      continent  \
# Afghanistan                                 0.0   34.660.000           Asia
# Albania                                     4.9    2.876.000         Europe
# Algeria                                     0.7   40.061.000         Africa
# Andorra                                    12.4   77.281.000         Europe
# Angola                                      5.9   28.081.000         Africa
# Antigua & Barbuda                           4.9       86.295  North America
# Argentina                                   8.3   43.085.000  South America
# Armenia                                     3.8    2.925.000         Europe
# Australia                                  10.4   24.013.000        Oceania
# Austria                                     9.7    8.725.111         Europe
# Azerbaijan                                  1.3    9.654.900         Europe
# Bahamas                                     6.3      368.390  North America
# Bahrain                                     2.0    1.359.800           Asia
# Bangladesh                                  0.0  159.145.000           Asia
# Barbados                                    6.3      285.000  North America
# Belarus                                    14.4    9.485.300         Europe
# Belgium                                    10.5   11.250.659         Europe
# Belize                                      6.8      368.310  North America
# Benin                                       1.1   10.315.244         Africa
# Bhutan                                      0.4      765.650           Asia
#
#                   consumo
# Afghanistan         Baixo
# Albania             Baixo
# Algeria               NaN
# Andorra              Alto
# Angola                NaN
# Antigua & Barbuda     NaN
# Argentina             NaN
# Armenia               NaN
# Australia             NaN
# Austria               NaN
# Azerbaijan            NaN
# Bahamas               NaN
# Bahrain               NaN
# Bangladesh            NaN
# Barbados              NaN
# Belarus               NaN
# Belgium               NaN
# Belize                NaN
# Benin                 NaN
# Bhutan                NaN
