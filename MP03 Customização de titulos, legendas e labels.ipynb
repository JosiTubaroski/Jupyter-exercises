# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = []
y = []
y2 = []

# %%
for num in range(-200,201,10):
    x.append(num)
    y.append(num)
    y2.append(2* num)

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

# %%
#Adicionando descrição aos eixos

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

#Primeira descrição
plt.xlabel("Eixo X")
# Out:
# Text(0.5, 0, 'Eixo X')

# %%
#Formatando a fonte descritiva do eixo

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

#Primeira descrição
plt.xlabel("Eixo X", color = "red", fontsize = 15)
# Out:
# Text(0.5, 0, 'Eixo X')

# %%
#Alinhamento dos textos descritivos

# %%
#Espaço livre a partir do ponto médio do eixo

plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

#Alinhamento a partir de 0

plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "right")
# Out:
# Text(0.5, 0, 'Espaço para o Eixo X')

# %%
#Y Label

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

#Realizando formatações no eixo X
plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Espaço para o Eixo Y", color = "blue", fontsize = 15, horizontalalignment = "center")
# Out:
# Text(0, 0.5, 'Espaço para o Eixo Y')

# %%
#Alinhamento vertical - Alinhamos o eixo Y verticalmente atraves da opção horizontalalignment

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

#Realizando formatações no eixo X
plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Espaço para o Eixo Y", color = "blue", fontsize = 15, horizontalalignment = "right")
# Out:
# Text(0, 0.5, 'Espaço para o Eixo Y')

# %%
#Adicionando Titulo

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

#Realizando formatações no eixo X
plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Espaço para o Eixo Y", color = "blue", fontsize = 15, horizontalalignment = "right")

#Title
plt.title("Título do Grafico", color = "gray", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Título do Grafico')

# %%
#Texto Matemático

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue")
plt.plot(x,y2, c = "green")

#Realizando formatações no eixo X
plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Espaço para o Eixo Y", color = "blue", fontsize = 15, horizontalalignment = "right")

#Title
plt.title(r"Título do Grafico $\frac{5}{4}$", color = "gray", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Título do Grafico $\\frac{5}{4}$')

# %%
#Labels e legendas

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue",
        label = "Primeiro")
plt.plot(x,y2, c = "green",
        label = "Segundo")

#Realizando formatações no eixo X
plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Espaço para o Eixo Y", color = "blue", fontsize = 15, horizontalalignment = "right")

#Title
plt.title(r"Título do Grafico $\frac{5}{4}$", color = "gray", fontsize = 25)
#Inserindo Legenda
plt.legend()

# %%
#Posição dos labels

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue",
        label = "Primeiro")
plt.plot(x,y2, c = "green",
        label = "Segundo")

#Realizando formatações no eixo X
plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Espaço para o Eixo Y", color = "blue", fontsize = 15, horizontalalignment = "right")

#Title
plt.title(r"Título do Grafico $\frac{5}{4}$", color = "gray", fontsize = 25)
#Inserindo Legenda
plt.legend(loc = "lower right")

# %%
# Customizando os eixos (Ticks)

# %%
plt.plot(x,y, c = "red", ls = "-", lw = 2, marker = 'o', ms = 10, fillstyle = "top", mfc = "blue",
        label = "Primeiro")
plt.plot(x,y2, c = "green",
        label = "Segundo")

#Realizando formatações no eixo X
plt.xlabel("Espaço para o Eixo X", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Espaço para o Eixo Y", color = "blue", fontsize = 15, horizontalalignment = "right")

#Title
plt.title(r"Título do Grafico $\frac{5}{4}$", color = "gray", fontsize = 25)
#Inserindo Legenda
plt.legend(loc = "lower right")

#Iniciando a customização dos eixos

eixoX = ["Janeiro", "Abril", "Julho"]

plt.xticks([-200,0,200],eixoX)
# Out:
# ([<matplotlib.axis.XTick at 0x240cdf3ee20>,
#   <matplotlib.axis.XTick at 0x240cdf3e0a0>,
#   <matplotlib.axis.XTick at 0x240ce0af850>],
#  [Text(-200, 0, 'Janeiro'), Text(0, 0, 'Abril'), Text(200, 0, 'Julho')])

# %%
#Customizando o Eixo Y

# %%
plt.plot(x,y, c = "red", ls = "-", label = "Produto A")
plt.plot(x,y2, c = "green", ls = ":", label = "Produto B")

#Realizando formatações no eixo X
plt.xlabel("Meses", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Classificação", color = "blue", fontsize = 15, horizontalalignment = "right")

plt.legend(loc = "lower right")

#Title
plt.title(r"Produtos em 2018", color = "gray", fontsize = 25)
#Inserindo Legenda

#Customização de eixo X e Y

eixoX = ["Janeiro", "Abril", "Julho"]
eixoY = ["Fraco", "Regular", "Neutro", "Bom", "Excelente"]

plt.xticks([-200,0,200],eixoX)
plt.yticks([-400,-100,0,100,400], eixoY)
# Out:
# ([<matplotlib.axis.YTick at 0x240cdf98730>,
#   <matplotlib.axis.YTick at 0x240cdf8ff70>,
#   <matplotlib.axis.YTick at 0x240cdf8f430>,
#   <matplotlib.axis.YTick at 0x240cdfcabe0>,
#   <matplotlib.axis.YTick at 0x240cdfd23a0>],
#  [Text(0, -400, 'Fraco'),
#   Text(0, -100, 'Regular'),
#   Text(0, 0, 'Neutro'),
#   Text(0, 100, 'Bom'),
#   Text(0, 400, 'Excelente')])

# %%
# Rotacionando tickets

# %%
eixoX = ["01/01/2018", "01/04/2018", "30/06/2018", "01/07/2018", "01/10/2018"]
eixoY = ["Fraco", "Regular", "Neutro", "Bom", "Excelente"]

plt.plot(x,y, c = "red", ls = "-", label = "Produto A")
plt.plot(x,y2, c = "green", ls = ":", label = "Produto B")

plt.xlabel("Datas", color = "red", fontsize = 15, horizontalalignment = "center")
plt.ylabel("Classificação", color = "blue", fontsize = 15, horizontalalignment = "center")

plt.title("Produtos",color = "gray", fontsize = 25)

plt.xticks([-200,-100,0,100,200],eixoX, rotation = 30)
plt.yticks([-400,-100,0,100,400],eixoY)

plt.legend(loc = "lower right")
